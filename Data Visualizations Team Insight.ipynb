# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib import style
style.use ("fivethirtyeight")

# %%
data=pd.read_csv('../input/state-unemployment-rate-change-march-to-april-2020/States_with_statistically_significant_unemployment_rate_changes_from_March_2020_to_April_2020_season.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#    State  March 2020 (Rate)  April 2020 (p-Rate)  Over-the-month change (p)
# 16    KS                2.8                 11.2                        8.4
# 36    OK                2.9                 13.7                       10.8
# 48    WV                6.0                 15.2                        9.2
# 15    IA                3.3                 10.2                        6.9
# 2     AZ                6.1                 12.6                        6.5
# 40    SC                3.2                 12.1                        8.9
# 7     DE                5.0                 14.3                        9.3
# 42    TN                3.3                 14.7                       11.4
# 41    SD                3.1                 10.2                        7.1
# 8     CD                6.0                 11.1                        5.1

# %%
State = df ['State']
march = df ['March 2020 (Rate)']
april = df ['April 2020 (p-Rate)']
y_pos = np.arange(len(State))

# %%
plt.bar(y_pos, march, align='center', alpha=.80)
plt.bar(y_pos, april, align='edge', alpha=0.75)
plt.xticks(y_pos, State)
plt.ylabel('\nUnemployment Rate (Percentage)\n')
plt.title('\nUnemployment Rate In Different US States From March to April in 2020\n')
plt.grid (True, color='gray')
months=['March 2020', 'April 2020']
plt.legend(months)
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/state-employment-changes-march-to-april-2020/States_with_statistically_significant_employment_changes_from_March_2020_to_April_2020_seasonally_ad.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#    State  March 2020  April 2020 (p)  Over-the-month change on Level (p)  \
# 13    IL     6060900         5298700                             -762200
# 47    WA     3495400         2968400                             -527000
# 49    WI     2967800         2528400                             -439400
# 36    OK     1686900         1556100                             -130800
# 28    NV     1404600         1159800                             -244800
# 1     AK      325700          281900                              -43800
# 44    UT     1582700         1446100                             -136600
# 42    TN     3147800         2770900                             -376900
# 19    ME      630100          531700                              -98400
# 10    GA     4618600         4126500                             -492100
#
#     Over-the-month change on Percent
# 13                             -12.6
# 47                             -15.1
# 49                             -14.8
# 36                              -7.8
# 28                             -17.4
# 1                              -13.4
# 44                              -8.6
# 42                             -12.0
# 19                             -15.6
# 10                             -10.7

# %%
State = df ['State']
march = df ['March 2020']
april = df ['April 2020 (p)']
y_pos = np.arange(len(State))

# %%
plt.bar(y_pos, march, align='center', color='#E0115F', alpha=.80)
plt.bar(y_pos, april, align='center', color='#002147',alpha=0.75)
plt.xticks(y_pos, State)
plt.ylabel('\nEmployed Population\n')
plt.title('\nEmployment Change In Different US States From March to April in 2020\n')
plt.grid (False, color='grey')
months=['March 2020', 'April 2020']
plt.legend(months)
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/local-unemployment-report-district-of-columbia/Local Unemployment Report District of Columbia.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#      Year Period labor_force participation_rate employment_population_ratio  \
# 100  2018    May        70.6               66.6                   405215(R)
# 13   2011    Feb        68.3               61.6                      349978
# 96   2018    Jan        70.6               66.5                   403941(R)
# 26   2012    Mar        68.3               61.8                      357875
# 49   2014    Feb        68.8               63.3                      373893
# 112  2019    May        70.9               67.0                   409126(R)
# 109  2019    Feb        70.7               66.6                   407526(R)
# 5    2010    Jun        69.0               62.6                      347745
# 56   2014    Sep        69.8               64.5                      382944
# 90   2017    Jul        70.4               66.1                   401520(R)
#
#     labor_force.1 employment unemployment  unemployment_rate
# 100     381984(R)   23231(R)       5.7(R)                NaN
# 13         315513      34465          9.8                NaN
# 96      380575(R)   23366(R)       5.8(R)                NaN
# 26         324111      33764          9.4                NaN
# 49         344167      29726          8.0                NaN
# 112     386492(R)   22634(R)       5.5(R)                NaN
# 109     384015(R)   23511(R)       5.8(R)                NaN
# 5          315533      32212          9.3                NaN
# 56         353547      29397          7.7                NaN
# 90      376715(R)   24805(R)       6.2(R)                NaN

# %%
months = df ['Period'].tail(12)
unemployed = df ['unemployment'].tail(12)

# %%
plt.plot (months,unemployed, label='Unemployed Population', color='#ffd700')
plt.title ("\nUnemployment Statistics In District of Columbia From May 2019 to April 2020\n", color='k')
plt.xlabel ("\nLast 12 Months\n", color= 'k')
plt.ylabel ("\nUnemployed Population\n", color= 'k')
plt.legend ()
plt.grid (True, color='#6E8B3D')
plt.rcParams['figure.figsize'] = [20, 10]
plt.show()

# %%
data=pd.read_csv('../input/state-unemployment-rates-april-2020/States_with_new_series_high_unemployment_rates_April_2020_seasonally_adjusted_-_Sheet1.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#    State  Rate(p)
# 13    KY     15.4
# 6     GA     11.9
# 20    MT     11.3
# 31    OR     14.2
# 24    NJ     15.3
# 40    VA     10.6
# 42    WI     14.1
# 39    VT     15.6
# 32    PA     15.1
# 35    SD     10.2

# %%
States = df ['State']
rate = df ['Rate(p)']
y_pos = np.arange(len(States))

# %%
plt.bar(y_pos, rate, color='#8B008B', align='center', alpha=.70)
plt.xticks(y_pos, States)
plt.ylabel('\nUnemployment Rate (Percentage)\n')
plt.title('\nUnemployment Rate In Different US States\n')
plt.grid (True, color='gray')
plt.rcParams['figure.figsize'] = [25, 10]
plt.show()

# %%
data=pd.read_csv('../input/who-covid19-us-data/WHO-COVID-19-US-Data.csv')
df=pd.DataFrame (data)
df.sample(10)
# Out:
#             Date_reported Country_code                   Country WHO_region  \
# 87   2020-04.16T00:00:00Z           US  United States of America       AMRO
# 105  2020-05.04T00:00:00Z           US  United States of America       AMRO
# 47   2020-03.07T00:00:00Z           US  United States of America       AMRO
# 23   2020-02.12T00:00:00Z           US  United States of America       AMRO
# 107  2020-05.06T00:00:00Z           US  United States of America       AMRO
# 102  2020-05.01T00:00:00Z           US  United States of America       AMRO
# 80   2020-04.09T00:00:00Z           US  United States of America       AMRO
# 6    2020-01.26T00:00:00Z           US  United States of America       AMRO
# 74   2020-04.03T00:00:00Z           US  United States of America       AMRO
# 100  2020-04.29T00:00:00Z           US  United States of America       AMRO
#
#      New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 87       25802            604070        2395              25871
# 105      31839           1125719       -1696              60710
# 47           0               213           0                 11
# 23           0                13           0                  0
# 107      16200           1171185         792              62698
# 102      31379           1035353        2909              55337
# 80       31709            395030        1895              12740
# 6            3                 5           0                  0
# 74       26298            213600         947               4793
# 100      22541            983457        1322              50492

# %%
date = df ['Date_reported'].tail(62)
covid_positive_cumulative = df ['Cumulative_cases'].tail(62)
deaths_cumulative = df ['Cumulative_deaths'].tail(62)
y_pos = np.arange(len(date))

# %%
plt.bar(y_pos, covid_positive_cumulative, align='center', color='#00008B', alpha=.80),
plt.bar(y_pos, deaths_cumulative, align='center', color='#A40000',alpha=0.75),
plt.xticks(y_pos)
plt.ylabel('\nCumulative Number\n')
plt.title('\nSpread of COVID19 in US from 27.03.2020 to 27.05.2020\n')
plt.grid (True, color='grey')
leg=['Cumulative COVID Positive Cases', 'Cumulative Deaths']
plt.legend(leg)
plt.rcParams['figure.figsize'] = [25, 10]
plt.show()

# %%
data=pd.read_csv('../input/new-york-mobility-report/New York Mobility Report.csv')
df=pd.DataFrame (data)
df.sample (10)
# Out:
#    country_region_code   country_region  sub_region_1  sub_region_2   \
# 79                   US   United States      New York
# 75                   US   United States      New York
# 47                   US   United States      New York
# 51                   US   United States      New York
# 38                   US   United States      New York
# 26                   US   United States      New York
# 92                   US   United States      New York
# 54                   US   United States      New York
# 48                   US   United States      New York
# 29                   US   United States      New York
#
#           Date   retail_and_recreation_percent_change_from_baseline   \
# 79  2020-05.04                                                 -51
# 75  2020-04.30                                                 -58
# 47  2020-04.02                                                 -54
# 51  2020-04.06                                                 -53
# 38  2020-03.24                                                 -53
# 26  2020-03.12                                                   1
# 92  2020-05.17                                                 -47
# 54  2020-04.09                                                 -65
# 48  2020-04.03                                                 -57
# 29  2020-03.15                                                 -14
#
#     grocery_and_pharmacy_percent_change_from_baseline   \
# 79                                                -17
# 75                                                -21
# 47                                                -20
# 51                                                -21
# 38                                                -18
# 26                                                 27
# 92                                                -15
# 54                                                -15
# 48                                                -22
# 29                                                 14
#
#     parks_percent_change_from_baseline   \
# 79                                  -11
# 75                                  -45
# 47                                  -26
# 51                                   -3
# 38                                  -16
# 26                                    6
# 92                                   54
# 54                                  -46
# 48                                  -56
# 29                                   28
#
#     transit_stations_percent_change_from_baseline   \
# 79                                             -64
# 75                                             -69
# 47                                             -69
# 51                                             -69
# 38                                             -63
# 26                                             -13
# 92                                             -56
# 54                                             -73
# 48                                             -70
# 29                                             -25
#
#     workplaces_percent_change_from_baseline   \
# 79                                       -55
# 75                                       -58
# 47                                       -62
# 51                                       -62
# 38                                       -56
# 26                                        -3
# 92                                       -31
# 54                                       -65
# 48                                       -62
# 29                                        -7
#
#     residential_percent_change_from_baseline
# 79                                        23
# 75                                        26
# 47                                        27
# 51                                        26
# 38                                        25
# 26                                         2
# 92                                        10
# 54                                        29
# 48                                        30
# 29                                         4

# %%
date = df ['Date '].tail(91)
retail = df ['retail_and_recreation_percent_change_from_baseline '].tail(91)
grocery = df ['grocery_and_pharmacy_percent_change_from_baseline '].tail(91)
parks = df ['parks_percent_change_from_baseline '].tail(91)
transit = df ['transit_stations_percent_change_from_baseline '].tail(91)
y_pos = np.arange(len(date))

# %%
plt.bar(y_pos, parks, align='center', width=0.5, color='#006B3C', alpha=.80),
plt.bar(y_pos, grocery, align='center', color='#7B3F00',alpha=0.75),
plt.xticks(y_pos)
plt.ylabel('\nRate of Change\n')
plt.title('\nChange in Activity of New York People in 25.02.2020 to 25.05.2020\n')
plt.grid (True, color='grey')
leg=['Parks', 'Grocery Shops']
plt.legend(leg)
plt.rcParams['figure.figsize'] = [30, 15]
plt.show()
